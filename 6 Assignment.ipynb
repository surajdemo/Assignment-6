# %%
#Assignment 1
# 1. Create a JSON file (employee.json) containing employee information of minimum 5 employees. Each employee information consists of Name, DOB, Height, City, State. Write a python program that reads this information from the JSON file and saves the information into a list of objects of Employee class. Finally print the list of the Employee objects.

#2. Create a dictionary of any 7 Indian states and their capitals.. Write this into a JSON file.



import json


Employees=[
{
"Name":"suraj",
"Height":"169cm",
"DOB":"10/7/1998",
"City":"Mumbai",
"state":"Maharashtra"
},
{
"Name":"sandip",
"Height":"168cm",
"DOB":"10/7/1999",
"City":"Pune",
"state":"Maharashtra"
},
{
"Name":"surya",
"Height":"179cm",
"DOB":"10/7/1995",
"City":"Thane",
"state":"Maharashtra"
},
{
"Name":"Rishabh",
"Height":"160cm",
"DOB":"10/7/1996",
"City":"Navi Mumbai",
"state":"Maharashtra"
},
{
"Name":"Aakash",
"Height":"160cm",
"DOB":"10/7/1994",
"City":"Nashik",
"state":"Maharashtra"
}
]




json_object = json.dumps(Employees, indent = 4) 
print(json_object)

with open("Employees.json","w")as file:
    json.dump(Employees,file)
# Out:
# [
#     {
#         "Name": "suraj",
#         "Height": "169cm",
#         "DOB": "10/7/1998",
#         "City": "Mumbai",
#         "state": "Maharashtra"
#     },
#     {
#         "Name": "sandip",
#         "Height": "168cm",
#         "DOB": "10/7/1999",
#         "City": "Pune",
#         "state": "Maharashtra"
#     },
#     {
#         "Name": "surya",
#         "Height": "179cm",
#         "DOB": "10/7/1995",
#         "City": "Thane",
#         "state": "Maharashtra"
#     },
#     {
#         "Name": "Rishabh",
#         "Height": "160cm",
#         "DOB": "10/7/1996",
#         "City": "Navi Mumbai",
#         "state": "Maharashtra"
#     },
#     {
#         "Name": "Aakash",
#         "Height": "160cm",
#         "DOB": "10/7/1994",
#         "City": "Nashik",
#         "state": "Maharashtra"
#     }
# ]

# %%
import json

{
"Employees":[
{
"Name":"suraj",
"Height":"169cm",
"DOB":"10/7/1998",
"City":"Mumbai",
"state":"Maharashtra"
},
{
"Name":"sandip",
"Height":"168cm",
"DOB":"10/7/1999",
"City":"Pune",
"state":"Maharashtra"
},
{
"Name":"surya",
"Height":"179cm",
"DOB":"10/7/1995",
"City":"Thane",
"state":"Maharashtra"
},
{
"Name":"Rishabh",
"Height":"160cm",
"DOB":"10/7/1996",
"City":"Navi Mumbai",
"state":"Maharashtra"
},
{
"Name":"Aakash",
"Height":"160cm",
"DOB":"10/7/1994",
"City":"Nashik",
"state":"Maharashtra"
}
]
}


with open('Employees.json')as f:
    data = json.load(f)
  
for i in data:
    print(i)
# Out:
# {'Name': 'suraj', 'Height': '169cm', 'DOB': '10/7/1998', 'City': 'Mumbai', 'state': 'Maharashtra'}
# {'Name': 'sandip', 'Height': '168cm', 'DOB': '10/7/1999', 'City': 'Pune', 'state': 'Maharashtra'}
# {'Name': 'surya', 'Height': '179cm', 'DOB': '10/7/1995', 'City': 'Thane', 'state': 'Maharashtra'}
# {'Name': 'Rishabh', 'Height': '160cm', 'DOB': '10/7/1996', 'City': 'Navi Mumbai', 'state': 'Maharashtra'}
# {'Name': 'Aakash', 'Height': '160cm', 'DOB': '10/7/1994', 'City': 'Nashik', 'state': 'Maharashtra'}

# %%
#2.
import json

dictionary ={"maharashtra" : "mumbai",
             "uttar pradesh" : "Lakhnow",
             "madhya pradesh" : "Bhopal",
             "Bihar" : "patna",
             "chattisghar":"raipur",
             "karnataka":"banglore"
            }




json_object = json.dumps(dictionary, indent = 4) 
print(json_object)

with open("sample.json", "w") as file:
 json.dump(dictionary, file)
# Out:
# {
#     "maharashtra": "mumbai",
#     "uttar pradesh": "Lakhnow",
#     "madhya pradesh": "Bhopal",
#     "Bihar": "patna",
#     "chattisghar": "raipur",
#     "karnataka": "banglore"
# }

# %%
#Assignment 2
# 1. Create a class named ‘Dog’. It should have a constructor which accepts its name, age and coat color. You must perform the following operations:



class Dog:
    def __init__ (self,name,age,coat_color):
        self.name=name
        self.age=age
        self.coat_color=coat_color
        
    def description(self):
        print("the name of a dog",self.name)
        print("the age of a dog",self.age)
    def get_info(self):
        print("the coat_color of the dog",self.coat_color)
        
        
class jackrussellterrie(Dog):
    def info(self):
        print("the name of the jack is qutee",)
    def get(self):
        print("the info is given correct")
        
        
class bulldog(jackrussellterrie):
    def set(self):
        print("the name of the bulldog is shera")
    def xyz(self):
        print("the age of the bull dog is not required")

        
x=bulldog('sweety',5,'white')
x.description()
x.get_info()
x.info()
x.get()
x.set()
x.xyz()
# Out:
# the name of a dog sweety
# the age of a dog 5
# the coat_color of the dog white
# the name of the jack is qutee
# the info is given correct
# the name of the bulldog is shera
# the age of the bull dog is not required
